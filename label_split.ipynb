# %%
import os
all_train_files = os.listdir(r"C:\Users\tyyp-\Desktop\Repository\Computer Vision\YOLO\PPE_Object_Detection\data\train\labels")
all_train_files
# Out:
# ['000002_jpg.rf.31f2cd35d1b9aaa764f7a0836591d3c3.txt',
#  '000003_jpg.rf.51b126505df000f6bbf6b965aac0f62e.txt',
#  '000004_jpg.rf.7cd7b3740fa78e99c877ce71a36949c3.txt',
#  '000006_jpg.rf.67f9e25e69985fca1ebe415b1f4dfdb5.txt',
#  '000007_jpg.rf.144157e581cf4c36a1287ba88eb12d54.txt',
#  '000010_jpg.rf.e4bd168a9c2344e569cbc839f49967a4.txt',
#  '000011_jpg.rf.0deccc7aa6db8d9491709ffd7ef0f880.txt',
#  '000012_jpg.rf.834defa565497913bc9305208b0e212b.txt',
#  '000013_jpg.rf.8ef8b7161c252abac97e7722d11e942e.txt',
#  '000014_jpg.rf.a876d523cc6bf412b79238954d18ce28.txt',
#  '000015_jpg.rf.0c0cedbd11befb87888bc8887dca5a52.txt',
#  '000016_jpg.rf.48148594e56e1e56e0c8f2c35f919daa.txt',
#  '000017_jpg.rf.61cc2c329f5708da1085381fcfc7f926.txt',
#  '000018_jpg.rf.355735099fcd9c0c85f385df7b89e80f.txt',
#  '000019_jpg.rf.5331107c69f1692d0fdd384033a5681a.txt',
#  '000022_jpg.rf.2a635c301afe1e6307492e6b8290ba36.txt',
#  '000023_jpg.rf.8973c5f53b053f1932167407b4928803.txt',
# ...

# %%
all_val_files = os.listdir(r"C:\Users\tyyp-\Desktop\Repository\Computer Vision\YOLO\PPE_Object_Detection\data\val\labels")
all_val_files
# Out:
# ['000001_jpg.rf.df25c3d751ae509dc90ba56fd301f1b0.txt',
#  '000005_jpg.rf.ec6c3148d49dc4a53436ba014c4e6938.txt',
#  '000008_jpg.rf.ee13f076cf1899a9129507d5e56718f8.txt',
#  '000009_jpg.rf.9a173193e5e0256092be17ca53df09e4.txt',
#  '000020_jpg.rf.679813eb0ea33e14bcc2d80c0d8d6414.txt',
#  '000021_jpg.rf.fdc55ecd2faffc17938e897515db461f.txt',
#  '000028_jpg.rf.df1b3be0ccdee2ecf4e849cacd663078.txt',
#  '000031_jpg.rf.f5ad6270779231f9e852a9e677c2242e.txt',
#  '000037_jpg.rf.0dde68f2a7b8721f99dcae5d9d6eb34d.txt',
#  '000038_jpg.rf.3f49366492a5995bbc9e6e9769ba5e5f.txt',
#  '000040_jpg.rf.1ae3f8cf87f89fc355098202003e2fa6.txt',
#  '000042_jpg.rf.636ddb3aa20be6bdec90b22f5ad8e0a7.txt',
#  '000045_jpg.rf.4a2464d92092f3db2e7195b0c010a3c6.txt',
#  '000047_jpg.rf.a783deaf8f69e190c439890a2cc8f86f.txt',
#  '000058_jpg.rf.6237243ba68525c619dd7a767bc10209.txt',
#  '000062_jpg.rf.e7c804d8bc5c9e819d554c85cb00e5b5.txt',
#  '000063_jpg.rf.262a66251a7af2d2eb4f56eeb3298e74.txt',
# ...

# %%
all_test_files = os.listdir(r"C:\Users\tyyp-\Desktop\Repository\Computer Vision\YOLO\PPE_Object_Detection\data\test\labels")
all_val_files
# Out:
# ['000001_jpg.rf.df25c3d751ae509dc90ba56fd301f1b0.txt',
#  '000005_jpg.rf.ec6c3148d49dc4a53436ba014c4e6938.txt',
#  '000008_jpg.rf.ee13f076cf1899a9129507d5e56718f8.txt',
#  '000009_jpg.rf.9a173193e5e0256092be17ca53df09e4.txt',
#  '000020_jpg.rf.679813eb0ea33e14bcc2d80c0d8d6414.txt',
#  '000021_jpg.rf.fdc55ecd2faffc17938e897515db461f.txt',
#  '000028_jpg.rf.df1b3be0ccdee2ecf4e849cacd663078.txt',
#  '000031_jpg.rf.f5ad6270779231f9e852a9e677c2242e.txt',
#  '000037_jpg.rf.0dde68f2a7b8721f99dcae5d9d6eb34d.txt',
#  '000038_jpg.rf.3f49366492a5995bbc9e6e9769ba5e5f.txt',
#  '000040_jpg.rf.1ae3f8cf87f89fc355098202003e2fa6.txt',
#  '000042_jpg.rf.636ddb3aa20be6bdec90b22f5ad8e0a7.txt',
#  '000045_jpg.rf.4a2464d92092f3db2e7195b0c010a3c6.txt',
#  '000047_jpg.rf.a783deaf8f69e190c439890a2cc8f86f.txt',
#  '000058_jpg.rf.6237243ba68525c619dd7a767bc10209.txt',
#  '000062_jpg.rf.e7c804d8bc5c9e819d554c85cb00e5b5.txt',
#  '000063_jpg.rf.262a66251a7af2d2eb4f56eeb3298e74.txt',
# ...

# %%
# %cd "C:\Users\tyyp-\Desktop\Repository\Computer Vision\YOLO\PPE_Object_Detection\data\train\labels"
# Out:
# C:\Users\tyyp-\Desktop\Repository\Computer Vision\YOLO\PPE_Object_Detection\data\train\labels

# %%
# Removing 3rd class (Person)
def remove_labels(all_files):
    head = 0; hat = 0; person = 0

    for file in all_files:
        with open(file, "r") as fp:
            lines = fp.readlines()

        with open(file, "w") as fp:
            for line in lines:
                if line.strip(' ')[0] != str(2):
                    fp.write(line)
                else:
                    print(line.strip(' ')[0])

remove_labels(all_train_files)

# %%
number_labels(all_train_files)

# %%
# %cd "C:\Users\tyyp-\Desktop\Repository\Computer Vision\YOLO\PPE_Object_Detection\data\val\labels"
remove_labels(all_val_files)
# Out:
# C:\Users\tyyp-\Desktop\Repository\Computer Vision\YOLO\PPE_Object_Detection\data\val\labels
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2

# %%
remove_labels(all_val_files)

# %%
# %cd "C:\Users\tyyp-\Desktop\Repository\Computer Vision\YOLO\PPE_Object_Detection\data\test\labels"
remove_labels(all_test_files)
# Out:
# C:\Users\tyyp-\Desktop\Repository\Computer Vision\YOLO\PPE_Object_Detection\data\test\labels
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2

# %%
remove_labels(all_test_files)
